# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# #### The dataset is about the smartphones from e-commerce website flipkart. It contains about the 835 data of various smartphones available in the market.

# %%
df=pd.read_csv("D:/flipkart_smartphones.csv")

# %%
df
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             836 non-null    object
#  1   model             836 non-null    object
#  2   colour            831 non-null    object
#  3   original_price    836 non-null    int64
#  4   discounted_price  836 non-null    int64
#  5   ratings           835 non-null    float64
#  6   rating_count      836 non-null    int64
#  7   reviews           836 non-null    int64
#  8   memory            757 non-null    float64
#  9   storage           820 non-null    float64
#  10  processor         698 non-null    object
#  11  rear_camera       836 non-null    object
#  12  front_camera      707 non-null    object
#  13  display_size      836 non-null    float64
#  14  battery_capacity  778 non-null    float64
#  15  battery_type      477 non-null    object
# ...

# %%
mat.hist(df['reviews'])
mat.yscale('log')
mat.show()

# %% [markdown]
# ### In this dataset, it shows us the basic stastical data of dataset,like count,mean,STD,min,0th percentile,2th percentile

# %%
mat.boxplot(df['reviews'])
mat.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### In this data set the boxplot data set. its on highest data of 12000 in the case. out lare comes in 6000and 4000.

# %% [markdown]
# ####

# %%
mat.hist(df['memory'],color='r')
mat.show()

# %%
mat.scatter(df['brand'],df['reviews'])

mat.xlabel("name")
mat.xticks(color='y',rotation=90,fontweight='bold',fontsize='10',horizontalalignment='right')
mat.show()

# %%
sea.distplot(df['original_price'],color='b')
mat.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\625504603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(df['original_price'],color='b')

# %%
sea.distplot(df['original_price'][:15000],rug=True,color='y')
mat.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\3788493698.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(df['original_price'][:15000],rug=True,color='y')

# %%
sea.distplot(df['original_price'],hist=False,color='r')
mat.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\4176207738.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(df['original_price'],hist=False,color='r')

# %%
sea.boxplot(x=df['discounted_price'])
mat.title('discounted_price')
mat.show()

# %%
sea.boxplot(y=df['discounted_price'])
mat.title('discounted_price')
mat.show()

# %%
#subplot 1
mat.subplot(3,3,1)
#mat.title('original_price')
sea.distplot(df['original_price'])

#subplot 2
mat.subplot(3,3,2)
#mat.tile('discounted_price')
sea.distplot(df['discounted_price'])

#subplot 3
mat.subplot(3,3,3)
#mat.title('reviews')
sea.distplot(df['reviews'])

mat.tight_layout()
mat.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\1315871206.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sea.distplot(df['original_price'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_20780\1315871206.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df1=df[(df.original_price>10000)&(df.discounted_price>1000)]
sea.jointplot(x='original_price', y='discounted_price',data=df1)
mat.show()

# %%
df1=df[(df.original_price>10000)&(df.discounted_price>1000)]
sea.jointplot(x='original_price', y='discounted_price',data=df1,kind="hex",color="r")
mat.show()
